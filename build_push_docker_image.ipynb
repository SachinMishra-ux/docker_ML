# %% [markdown]
# ## Containerize model server & ML API with Docker Build and push docker images to docker-repository
# ### One common way of distributing this model API server for production deployment, is via Docker containers.

# %%
# Replace {docker_username} with your Docker Hub username
docker_username = 'sachin19566'
# Build and tage docker images
# !docker build -t {docker_username}/fastapi-placement-classifier:1.0.1 .
# Out:
# [+] Building 0.0s (0/2)
# [+] Building 0.2s (2/3)
#  => [internal] load build definition from Dockerfile                       0.0s
#  => => transferring dockerfile: 401B                                       0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [internal] load metadata for docker.io/tiangolo/uvicorn-gunicorn-fast  0.1s
# [+] Building 0.3s (2/3)
#  => [internal] load build definition from Dockerfile                       0.0s
#  => => transferring dockerfile: 401B                                       0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [internal] load metadata for docker.io/tiangolo/uvicorn-gunicorn-fast  0.3s
# [+] Building 0.5s (2/3)
# ...

# %%
# Push Docker images to Docker hub (Public repository)
# !docker push {docker_username}/fastapi-placement-classifier:1.0.1
# Out:
# The push refers to repository [docker.io/sachin19566/fastapi-placement-classifier]
#
# 5930b67f: Preparing
# 2000c8ea: Preparing
# 8f4b8ecd: Preparing
# c1ab72ab: Preparing
# 8074afd3: Preparing
# 706a2ee5: Preparing
# 4283af9c: Preparing
# e5a810ad: Preparing
# f53ce74f: Preparing
# 49af7706: Preparing
# 8214934e: Preparing
# 78a401d7: Preparing
# d94877ae: Preparing
# b0619b40: Preparing
# 8df170d3: Preparing
# f19d0440: Preparing
# 54ad0b1d: Preparing
# 679534ad: Preparing
# 66bcf3b5: Preparing
# 420135e3: Preparing
# f5c5ff9f: Preparing
# 24a95c80: Preparing
# f4b8ecd: Pushed     506MB/497.3MBicorn-gunicorn-fastapi 1.0.1: digest: sha256:5c0835d63a87ca47a9bb8dfd7dfe1fea4019ee2a887b40757697fa9d85d83f68 size: 5131

# %% [markdown]
# ### Run containerize model server - Ready to receive request

# %%
# For full documentation please refere https://github.com/tiangolo/uvicorn-gunicorn-fastapi-docker
# !docker run --name fastapi-server -d -p 80:80 -e WORKERS_PER_CORE="3" {docker_username}/fastapi-placement-classifier:1.0.1
# Out:
# 70f59fb3c786308cea6b5140a8ed8ef6b2cdfe2fc4449fb79a281041d7c9834e

# %% [markdown]
# ## Send request to Local FastAPI model server The Fast API server also provides a simple web UI dashboard (Swagger).
# ### Go to http://0.0.0.0:80/docs in the browser and use the Web UI to send prediction request:

# %% [markdown]
# ### Send Batch of test request from Python program or from python command prompt

# %%
import requests
data = {
  "sl_no": 112,
  "ssc_p": 84.0,
  "hsc_p": 90.9,
  "degree_p": 64.5,
  "etest_p": 86.04,
  "mba_p": 59.42,
  "gender": "M",
  "ssc_b": "Others",
  "hsc_b": "Others",
  "hsc_s": "Science",
  "degree_t": "Sci&Tech",
  "workex": "No",
  "specialisation": "Mkt&Fin"
}
response = requests.post("http://0.0.0.0:80/predict", json=data)
print(response.text)
# Out:
# {"prediction":["Placed"]}

# %%
data = {
  "sl_no": 113,
  "ssc_p": 52.0,
  "hsc_p": 57.0,
  "degree_p": 50.8,
  "etest_p": 67.0,
  "mba_p": 62.79,
  "gender": "M",
  "ssc_b": "Central",
  "hsc_b": "Central",
  "hsc_s": "Commerce",
  "degree_t": "Comm&Mgmt",
  "workex": "No",
  "specialisation": "Mkt&HR"
}
response = requests.post("http://0.0.0.0:80/predict", json=data)
print(response.text)
# Out:
# {"prediction":["Not Placed"]}

# %% [markdown]
# ### Check Docker logs

# %%
# !docker logs 70f59fb3c786308cea6b5140a8
# Out:
# Error response from daemon: No such container: 70f59fb3c786308cea6b5140a8

# %% [markdown]
# ### Stop and delete the running MLAPI container

# %%
# !docker stop 70f59fb3c786308cea6b5140a8
# !docker rm 70f59fb3c786308cea6b5140a8
# Out:
# 70f59fb3c786308cea6b5140a8
# 70f59fb3c786308cea6b5140a8
